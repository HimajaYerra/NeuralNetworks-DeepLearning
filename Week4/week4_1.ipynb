# %%
import pandas as pd

# %% [markdown]
# upload data.csv from your local

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f3174b3-e646-44e4-8d6a-41e962cdfc3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f3174b3-e646-44e4-8d6a-41e962cdfc3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('data.csv')

# %% [markdown]
# shows the top 5 rows in the dataset

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# to print the data types of all columns present in dataset

# %%
data.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %% [markdown]
# shows the stat descripription of Maxpulse column such as max,min,mean

# %%
data.Maxpulse.describe()
# Out:
# count    169.000000
# mean     134.047337
# std       16.450434
# min      100.000000
# 25%      124.000000
# 50%      131.000000
# 75%      141.000000
# max      184.000000
# Name: Maxpulse, dtype: float64

# %% [markdown]
# shows the stat descripription of Duration column such as max,min,mean

# %%
data.Duration.describe()
# Out:
# count    169.000000
# mean      63.846154
# std       42.299949
# min       15.000000
# 25%       45.000000
# 50%       60.000000
# 75%       60.000000
# max      300.000000
# Name: Duration, dtype: float64

# %% [markdown]
# to see the unique values present in a column Duration

# %%
data.Duration.unique()
# Out:
# array([ 60,  45,  30,  80,  20, 210, 160, 180, 150, 300,  90, 120, 270,
#         15,  25,  75])

# %%
data.Duration.value_counts()
# Out:
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 210     2
# 160     2
# 15      2
# 75      2
# 80      1
# 300     1
# 270     1
# 25      1
# Name: Duration, dtype: int64

# %%
data.Duration.plot(kind="hist")

# %% [markdown]
# shows the values where null values are present

# %%
data.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %% [markdown]
# fill the null values with mean value in the whole dataset

# %%
data = data.fillna(data.mean())
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# selects the dataset where calories are between 500 & 1000

# %%
res = data[(data["Calories"] > 500) & (data["Calories"] < 1000)]
res
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# filter data to show rows with calories > 500 and pulse < 100

# %%
y = data[(data["Calories"] > 500) & (data["Pulse"] < 100)]
y
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# created new dataframe by removing Maxpulse column

# %%
df_modified = data[["Duration","Pulse","Calories"]]
df_modified
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %% [markdown]
# deleted the Maxpulse column from original dataframe

# %%
del data['Maxpulse']
data
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %% [markdown]
# to check if any data is still null

# %%
data['Calories'].isnull().values.any()
# Out:
# False

# %% [markdown]
# convert the float values of calories to int

# %%
data['Calories'] = data['Calories'].astype(int)
data
# Out:
#      Duration  Pulse  Calories
# 0          60    110       409
# 1          60    117       479
# 2          60    103       340
# 3          45    109       282
# 4          45    117       406
# ..        ...    ...       ...
# 164        60    105       290
# 165        60    110       300
# 166        60    115       310
# 167        75    120       320
# 168        75    125       330
#
# [169 rows x 3 columns]

# %% [markdown]
# plot the duration and calories using pandas scatter plot

# %%
data.plot(x='Duration', y='Calories', style='o')
