# %%
import wordcloud
from wordcloud import WordCloud
import pandas as pd

# %%
# Read the text file
with open('whitelist.txt', 'r') as file:
    text = file.read()


# Create the word cloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(text)
  
# Display the generated image:
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
ext = tldextract.extract(url)
    tlds.append(ext.suffix)

# Create a DataFrame to store the TLD counts
tld_counts = pd.DataFrame({'TLD': tlds})

# Group the TLD counts by TLD and count the occurrences of each TLD
tld_counts = tld_counts.groupby('TLD').size().reset_index(name='count')

# Sort the TLD counts in descending order
tld_counts = tld_counts.sort_values(by='count', ascending=False)

# Print the top 10 TLDs and their counts
print(tld_counts.head(10))

# %%
df = pd.read_csv('phishing_database.csv')

# Extract the URLs from the 'url' column
urls = df['url']

# Combine the URLs into a single string
text = ' '.join(urls)


# Create the word cloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(text)
  
# Display the generated image:
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
